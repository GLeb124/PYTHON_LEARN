# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_csv('C:\\Users\\gsladyzh\\Downloads\\test_data_regno.csv', sep = ';', index_col='id')

# %%
test.head()
# Out:
#     camera_id time_check regno_recognize   regno_ai      regno  result_code  \
# id
# 1         844   00:00:00       У991КВ799  У991КВ799  У991КВ799            0
# 2        2516   00:00:00       О019УК177  О019УК177  О019УК177            0
# 3        2476   00:00:00       Е175АК150  Е175АК150  Е175АК150            0
# 4        1251   00:00:01       Т359ОН799  Т359ОН799  Т359ОН799            0
# 5        2516   00:00:01       В521СУ750  В521СУ750  В521СУ750            0
#
#                                           symbols  \
# id
# 1   ["У", "9", "9", "1", "К", "В", "7", "9", "9"]
# 2   ["О", "0", "1", "9", "У", "К", "1", "7", "7"]
# 3   ["Е", "1", "7", "5", "А", "К", "1", "5", "0"]
# 4   ["Т", "3", "5", "9", "О", "Н", "7", "9", "9"]
# 5   ["В", "5", "2", "1", "С", "У", "7", "5", "0"]
#
#                                         symbol_scores  \
# id
# 1   [0.9999366998672485, 0.9999223947525024, 0.999...
# 2   [0.9998993873596191, 0.999862790107727, 0.9999...
# 3   [0.9997256398200989, 0.9999269247055054, 0.999...
# 4   [0.9998781681060791, 0.9998764991760254, 0.999...
# 5   [0.999920129776001, 0.9999333620071411, 0.9999...
#
#                                         length_scores
# id
# 1   [0.000000034831597162110484, 0.000000034835451...
# 2   [0.0000000068477667980459955, 0.00000000683332...
# 3   [0.000000002039653557162069, 0.000000002043387...
# 4   [0.00000002880540606042814, 0.0000000289985120...
# 5   [0.000000009300508807541519, 0.000000009201486...

# %% [markdown]
# # Преобразование датасета

# %%
test['time_check'] = pd.to_datetime(test['time_check'])

# %%
test['Hour'] = pd.to_datetime(test['time_check'], format='%H:%M:%S').dt.hour

# %% [markdown]
# ## Преобразование length_scores в пандас серию

# %%
score_length = (pd.melt(test.length_scores.replace(['\]','\[','\,'],'',regex = True).str.split(' ').apply(pd.Series).reset_index(), 
             id_vars=['id'],
             value_name='length_scores')
     .set_index(['id'])
     .sort_index()
     )

# %%
score_length['variable'] = score_length['variable'].astype(int)

# %%
score_length = score_length.groupby('id').length_scores.agg('max')

# %%
test = test.merge(score_length, how = 'inner', on = 'id')

# %% [markdown]
# ### Количество знаков в ГРЗ

# %%
ss = test['symbol_scores'].str.split().apply(len)

# %%
test = test.merge(ss, how = 'inner', on = 'id')

# %%
test.head()
# Out:
#     camera_id          time_check regno_recognize   regno_ai      regno  \
# id
# 1         844 2022-04-13 00:00:00       У991КВ799  У991КВ799  У991КВ799
# 2        2516 2022-04-13 00:00:00       О019УК177  О019УК177  О019УК177
# 3        2476 2022-04-13 00:00:00       Е175АК150  Е175АК150  Е175АК150
# 4        1251 2022-04-13 00:00:01       Т359ОН799  Т359ОН799  Т359ОН799
# 5        2516 2022-04-13 00:00:01       В521СУ750  В521СУ750  В521СУ750
#
#     result_code                                        symbols  \
# id
# 1             0  ["У", "9", "9", "1", "К", "В", "7", "9", "9"]
# 2             0  ["О", "0", "1", "9", "У", "К", "1", "7", "7"]
# 3             0  ["Е", "1", "7", "5", "А", "К", "1", "5", "0"]
# 4             0  ["Т", "3", "5", "9", "О", "Н", "7", "9", "9"]
# 5             0  ["В", "5", "2", "1", "С", "У", "7", "5", "0"]
#
#                                         symbol_scores  \
# id
# 1   [0.9999366998672485, 0.9999223947525024, 0.999...
# 2   [0.9998993873596191, 0.999862790107727, 0.9999...
# 3   [0.9997256398200989, 0.9999269247055054, 0.999...
# 4   [0.9998781681060791, 0.9998764991760254, 0.999...
# 5   [0.999920129776001, 0.9999333620071411, 0.9999...
#
#                                         length_scores   length_scores_end  \
# id
# 1   [0.000000034831597162110484, 0.000000034835451...  0.9999313354492188
# 2   [0.0000000068477667980459955, 0.00000000683332...  0.9999903440475464
# 3   [0.000000002039653557162069, 0.000000002043387...  0.9999988079071045
# 4   [0.00000002880540606042814, 0.0000000289985120...  0.9999815225601196
# 5   [0.000000009300508807541519, 0.000000009201486...  0.9999921321868896
#
#     ...  Hour  pos_max_score_symbol symbols_max_score  score_max  \
# id  ...
# 1   ...     0                     0                 У   0.999937
# 2   ...     0                     8                 7   0.999973
# 3   ...     0                     2                 7   0.999964
# 4   ...     0                     2                 5   0.999909
# 5   ...     0                     8                 0   0.999971
#
#     pos_min_score_symbol symbols_min_score  score_min  score_max  score_min  \
# id
# 1                      8                 9   0.999081   0.999754   0.999754
# 2                      1                 0   0.999863   0.999911   0.999911
# 3                      0                 Е   0.999726   0.999882   0.999882
# 4                      6                 7   0.999265   0.999653   0.999653
# 5                      4                 С   0.999577   0.999892   0.999892
#
#     GRZ_score
# id
# 1    0.999754
# 2    0.999911
# 3    0.999882
# 4    0.999653
# 5    0.999892
#
# [5 rows x 21 columns]

# %%
# test.drop(columns=['GRZ_score','score_min'],axis = 1)
# test.drop(test.columns[[20, 19]], axis=1)
test
# Out:
#         camera_id          time_check regno_recognize   regno_ai      regno  \
# id
# 1             844 2022-04-14 00:00:00       У991КВ799  У991КВ799  У991КВ799
# 2            2516 2022-04-14 00:00:00       О019УК177  О019УК177  О019УК177
# 3            2476 2022-04-14 00:00:00       Е175АК150  Е175АК150  Е175АК150
# 4            1251 2022-04-14 00:00:01       Т359ОН799  Т359ОН799  Т359ОН799
# 5            2516 2022-04-14 00:00:01       В521СУ750  В521СУ750  В521СУ750
# ...           ...                 ...             ...        ...        ...
# 194210       5497 2022-04-14 23:59:58       В035Т_197  В035ТС197  В035Т_197
# 194211       6320 2022-04-14 23:59:58        А974КА67   А974КА67   А974КА67
# 194212       2659 2022-04-14 23:59:58       Х037НН777  Х037НН777  Х037НН777
# 194213        839 2022-04-14 23:59:59        С110ОС66   С110ОС69   С110ОС69
# 194214       1251 2022-04-14 23:59:59       Х772НР777  Х772НР777  Х772НР777
#
#         result_code                                        symbols  \
# id
# 1                 0  ["У", "9", "9", "1", "К", "В", "7", "9", "9"]
# 2                 0  ["О", "0", "1", "9", "У", "К", "1", "7", "7"]
# 3                 0  ["Е", "1", "7", "5", "А", "К", "1", "5", "0"]
# 4                 0  ["Т", "3", "5", "9", "О", "Н", "7", "9", "9"]
# 5                 0  ["В", "5", "2", "1", "С", "У", "7", "5", "0"]
# ...             ...                                            ...
# 194210            1  ["В", "0", "3", "5", "Т", "С", "1", "9", "7"]
# 194211            2       ["А", "9", "7", "4", "К", "А", "6", "7"]
# 194212            0  ["Х", "0", "3", "7", "Н", "Н", "7", "7", "7"]
# 194213            5       ["С", "1", "1", "0", "О", "С", "6", "9"]
# 194214            0  ["Х", "7", "7", "2", "Н", "Р", "7", "7", "7"]
#
#                                           symbol_scores_x  \
# id
# 1       [0.9999366998672485, 0.9999223947525024, 0.999...
# 2       [0.9998993873596191, 0.999862790107727, 0.9999...
# 3       [0.9997256398200989, 0.9999269247055054, 0.999...
# 4       [0.9998781681060791, 0.9998764991760254, 0.999...
# 5       [0.999920129776001, 0.9999333620071411, 0.9999...
# ...                                                   ...
# 194210  [0.9998652935028076, 0.9999170303344727, 0.999...
# 194211  [0.9999264478683472, 0.9999524354934692, 0.999...
# 194212  [0.9999473094940186, 0.9999399185180664, 0.999...
# 194213  [0.9999434947967529, 0.999817430973053, 0.9997...
# 194214  [0.9998537302017212, 0.9999246597290039, 0.999...
#
#                                           length_scores_x  Hour  \
# id
# 1       [0.000000034831597162110484, 0.000000034835451...     0
# 2       [0.0000000068477667980459955, 0.00000000683332...     0
# 3       [0.000000002039653557162069, 0.000000002043387...     0
# 4       [0.00000002880540606042814, 0.0000000289985120...     0
# 5       [0.000000009300508807541519, 0.000000009201486...     0
# ...                                                   ...   ...
# 194210  [0.000000012212018951629489, 0.000000012157821...    23
# 194211  [0.0000000026609143777278632, 0.00000000267139...    23
# 194212  [0.0000000758142704171405, 0.00000007637027721...    23
# 194213  [0.000000009674453238517344, 0.000000009729264...    23
# 194214  [0.00000003661622827166866, 0.0000000367221844...    23
#
#            length_scores_y  symbol_scores_y
# id
# 1       0.9999313354492188                9
# 2       0.9999903440475464                9
# 3       0.9999988079071045                9
# 4       0.9999815225601196                9
# 5       0.9999921321868896                9
# ...                    ...              ...
# 194210  0.9999971389770508                9
# 194211  0.9999985694885254                8
# 194212  0.9998723268508911                9
# 194213  0.9999716281890869                8
# 194214  0.9999825954437256                9
#
# [194214 rows x 12 columns]

# %% [markdown]
# ## Преобразование столбцов со списками в пандас.серии

# %%
symbols = (pd.melt(test.symbols.replace(['\]','\[','\,','\"'],'',regex = True).str.split(' ').apply(pd.Series).reset_index(), 
             id_vars=['id'],
             value_name='GRZ')
     .set_index(['id'])
     .sort_index()
     )

# %%
symbol_scores = (pd.melt(test.symbol_scores_x.replace(['\]','\[','\,','\"'],'',regex = True).str.split(' ').apply(pd.Series).reset_index(), 
             id_vars=['id'],
             value_name='GRZ_score')
     .set_index(['id'])
     .sort_index()
     )

# %%
score_GRZ = symbols.merge(symbol_scores,how = 'inner', on = ['id','variable'])

# %%
score_GRZ['GRZ_score'] = score_GRZ['GRZ_score'].astype(float)

# %% [markdown]
# ### поиск минимального и максимального скора по грз

# %%
max_score_GRZ = score_GRZ.groupby('id', as_index=False).apply(lambda x: x.nlargest(1,['GRZ_score'])).reset_index(level=0, drop=True)

# %%
mean_score_GRZ=score_GRZ.groupby('id').agg({'GRZ_score':'mean'})

# %%
min_score_GRZ = score_GRZ.groupby('id', as_index=False).apply(lambda x: x.nsmallest(1,['GRZ_score'])).reset_index(level=0, drop=True)

# %%
test = test.merge(max_score_GRZ,how='inner', on = 'id')

# %%
test = test.merge(min_score_GRZ,how='inner', on = 'id')

# %%
test = test.merge(mean_score_GRZ,how='inner', on = 'id')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194214 entries, 1 to 194214
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   camera_id        194214 non-null  int64
#  1   time_check       194214 non-null  datetime64[ns]
#  2   regno_recognize  194214 non-null  object
#  3   regno_ai         194214 non-null  object
#  4   regno            194214 non-null  object
#  5   result_code      194214 non-null  int64
#  6   symbols          194214 non-null  object
#  7   symbol_scores_x  194214 non-null  object
#  8   length_scores_x  194214 non-null  object
#  9   Hour             194214 non-null  int64
#  10  length_scores_y  194214 non-null  object
#  11  symbol_scores_y  194214 non-null  int64
#  12  variable_x       194214 non-null  object
#  13  GRZ_x            194214 non-null  object
#  14  GRZ_score_x      194214 non-null  float64
#  15  variable_y       194214 non-null  object
#  16  GRZ_y            194214 non-null  object
#  17  GRZ_score_y      194214 non-null  float64
#  18  GRZ_score        194214 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(11)
# memory usage: 29.6+ MB

# %%
test = test.rename(columns = {'symbol_scores_x': 'symbol_scores',
                      'length_scores_x':'length_scores',
                      'length_scores_y': 'length_scores_end',
                      'symbol_scores_y':'index_last_score',
                      'variable_x':'pos_max_score_symbol',
                      'GRZ_x':'symbols_max_score',
                      'GRZ_score_x':'score_max',
                      'variable_y':'pos_min_score_symbol',
                      'GRZ_y':'symbols_min_score',
                      'GRZ_score_y':'score_min',
                              'GRZ_score':'score_mean'})

# %% [markdown]
# length_scores_end = скор последнего элемента
# index_last_score = позиция последнего элемента
# pos_max_score_symbol = позиция символа с максимальным скором
# symbols_max_score = символ с максимальным скором
# score_max = максимальнй скор свимвола
# pos_min_score_symbol = позиция символа с минимальным скором
# symbols_min_score = символ с минимальным скором
# score_min = минимальный скор символа
# score_mean = средний скор по ГРЗ

# %% [markdown]
# ### фильтрация данных
# где новый алгоритм правильно предсказал грз, а старый предсказал неправильно

# %%
test_AI = test.loc[(test['regno_recognize'] != test['regno']) & (test['regno_ai'] == test['regno'])]
#

# %%
фильтрация данных, где новый алгоритм неправильно предсказал грз, а старый предсказал правильно

# %%
test_not_AI = test.loc[(test['regno_recognize'] == test['regno']) & (test['regno_ai'] != test['regno'])]
#

# %%
# test_AI_not_AI = test.loc[(test['regno_recognize'] == test['regno']) & (test['regno_ai'] == test['regno'])]
#                       тестирование

# %%
test_AI['length_scores_end'] = test_AI['length_scores_end'].astype(float)
# Out:
# <ipython-input-733-00df16df8c1d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_AI['length_scores_end'] = test_AI['length_scores_end'].astype(float)

# %%
test_not_AI['length_scores_end'] = test_not_AI['length_scores_end'].astype(float)
# Out:
# <ipython-input-734-ceefbcc68eb4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_not_AI['length_scores_end'] = test_not_AI['length_scores_end'].astype(float)

# %% [markdown]
# количество символов в грз,количество правильно предсказанных новым алгоритмом, и их средний скор

# %%
test_AI.groupby('index_last_score',as_index= False).agg({'index_last_score': ['mean', 'count'],'length_scores_end':'mean'})
# Out:
#   index_last_score       length_scores_end
#               mean count              mean
# 0                7   133          0.994523
# 1                8  1192          0.999683
# 2                9  8353          0.999821

# %% [markdown]
# количество символов в грз,количество неправильно предсказанных новым алгоритмом, и их средний скор

# %%
test_not_AI.groupby('index_last_score',as_index= False).agg({'index_last_score': ['mean', 'count'],'length_scores_end':'mean'})
# Out:
#   index_last_score       length_scores_end
#               mean count              mean
# 0                7  5009          0.894598
# 1                8  7711          0.955914
# 2                9  3710          0.982223

# %% [markdown]
# видно, что новый алгоритм лучше предсказывает грз если он состоит из 9 символов, но при этом хуже в остальных случаях

# %% [markdown]
# ### статистика по символам

# %%
AI = test_AI.groupby('symbols_max_score').agg({'score_max': 'mean','camera_id':'count'}).sort_values('symbols_max_score')

# %%
not_AI = test_not_AI.groupby('symbols_max_score').agg({'score_max': 'mean','camera_id': 'count'}).sort_values('symbols_max_score')

# %%
AI_min = test_AI.groupby('index_last_score',as_index= False).agg({'score_min': 'mean','camera_id':'count'}).sort_values('score_min')

# %%
not_AI_min = test_not_AI.groupby('index_last_score',as_index= False).agg({'score_min': 'mean','camera_id': 'count'}).sort_values('score_min')

# %%
AI = AI.merge(not_AI, how = 'outer', on='symbols_max_score' )

# %%
AI['razmah'] = AI['score_max_x'] - AI['score_max_y']

# %%
AI['razmah_count'] = AI['camera_id_x'] - AI['camera_id_y']

# %%
AI_min = AI_min.merge(not_AI_min, how = 'outer', on='index_last_score' )

# %%
AI_min['razmah_min'] = AI_min['score_min_x'] - AI_min['score_min_y']

# %%
AI_min['razmah_count_min'] = AI_min['camera_id_x'] - AI_min['camera_id_y']

# %%
AI_min
# Out:
#    index_last_score  score_min_x  camera_id_x  score_min_y  camera_id_y  \
# 0                 7     0.958628          133     0.442088         5009
# 1                 8     0.992096         1192     0.407800         7711
# 2                 9     0.997069         8353     0.802537         3710
#
#    razmah_min  razmah_count_min
# 0    0.516540             -4876
# 1    0.584296             -6519
# 2    0.194532              4643

# %%
AI
# Out:
#                    score_max_x  camera_id_x  score_max_y  camera_id_y  \
# symbols_max_score
# 0                     0.999969        571.0     0.964633         1842
# 1                     0.999981       1690.0     0.981904         1431
# 2                     0.999962        203.0     0.978899         1070
# 3                     0.999524        193.0     0.952603          413
# 4                     0.999964        290.0     0.979541          786
# 5                     0.999957        307.0     0.961613         1063
# 6                     0.999867        376.0     0.955988          543
# 7                     0.999981       3130.0     0.991339         3868
# 8                     0.999959        217.0     0.975065          846
# 9                     0.999982       1300.0     0.990472         1788
# А                     0.999976        346.0     0.981937          736
# В                     0.999965        148.0     0.966492          226
# Е                     0.999962        189.0     0.978046          482
# К                     0.999952         41.0     0.987346          280
# М                     0.999959        131.0     0.975573          203
# Н                     0.999957         71.0     0.973192           70
# О                     0.999960        131.0     0.975290           65
# Р                     0.999957        101.0     0.984290          162
# С                     0.999961         76.0     0.983593          174
# Т                     0.999954         24.0     0.961529           93
# У                     0.999948         49.0     0.975544           54
# Х                     0.999965         94.0     0.992966          220
# D                          NaN          NaN     0.794876           15
#
#                      razmah  razmah_count
# symbols_max_score
# 0                  0.035335       -1271.0
# 1                  0.018077         259.0
# 2                  0.021063        -867.0
# 3                  0.046921        -220.0
# 4                  0.020423        -496.0
# 5                  0.038344        -756.0
# 6                  0.043879        -167.0
# 7                  0.008642        -738.0
# 8                  0.024893        -629.0
# 9                  0.009510        -488.0
# А                  0.018039        -390.0
# В                  0.033473         -78.0
# Е                  0.021916        -293.0
# К                  0.012606        -239.0
# М                  0.024386         -72.0
# Н                  0.026765           1.0
# О                  0.024670          66.0
# Р                  0.015667         -61.0
# С                  0.016368         -98.0
# Т                  0.038425         -69.0
# У                  0.024404          -5.0
# Х                  0.006999        -126.0
# D                       NaN           NaN

# %%
AI_mean = test_AI.groupby('index_last_score').agg({'score_mean': 'mean','camera_id':'count'}).sort_values('index_last_score')

# %%
not_AI_mean = test_not_AI.groupby('index_last_score').agg({'score_mean': 'mean','camera_id': 'count'}).sort_values('index_last_score')

# %%
not_AI_mean
# Out:
#    index_last_score  score_mean  camera_id
# 0                 7    0.746371       5009
# 1                 8    0.771080       7711
# 2                 9    0.954174       3710

# %%
AI_mean = AI_mean.merge(not_AI_mean, how = 'outer', on='index_last_score')

# %%
AI_mean['razmah'] = AI_mean['score_mean_x'] - AI_mean['score_mean_y']

# %%
AI_mean['razmah_count'] = AI_mean['camera_id_x'] - AI_mean['camera_id_y']

# %%
AI_mean
# Out:
#    index_last_score  score_mean_x  camera_id_x  score_mean_y  camera_id_y  \
# 0                 7      0.991631          133      0.746371         5009
# 1                 8      0.998355         1192      0.771080         7711
# 2                 9      0.999530         8353      0.954174         3710
#
#      razmah  razmah_count
# 0  0.245261         -4876
# 1  0.227274         -6519
# 2  0.045356          4643

# %% [markdown]
# Наименьший разброс минимальных/средних скоров символов наблюдается в ГРЗ с количеством 9, также
# символ "D" новый алгоритм хуже всего распознает

# %% [markdown]
# ### Проверка на влияние времени суток на распознование ГРЗ

# %%
test_AI_1_hour = test_AI.groupby(['result_code','Hour'],as_index= False).agg({'camera_id':'count'})

# %%
plt.rcParams['figure.figsize']=10,10
sns.barplot(y = 'camera_id', x = 'Hour' , data = test_AI_1_hour, hue = 'result_code' )
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='camera_id'>

# %%
test_not_AI_hour = test_not_AI.groupby(['result_code','Hour'],as_index= False).agg({'camera_id':'count'})

# %%
sns.barplot(y = 'camera_id', x = 'Hour' , data = test_not_AI_hour, hue = 'result_code' )
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='camera_id'>

# %% [markdown]
# можно предположить, что в ночное время, новый алгоритм справляется лучше, т к пики приходятся на ночное время

# %%
AI_сamera = test_AI.groupby('camera_id',as_index = False).agg({'score_mean': 'mean','result_code':'count'}).sort_values('score_mean')

# %%
not_AI_camera = test_not_AI.groupby('camera_id',as_index = False).agg({'score_mean': 'mean','result_code':'count'}).sort_values('score_mean')

# %%
AI_сamera = AI_сamera.merge(not_AI_camera,how ='outer', on = 'camera_id')

# %%
AI_сamera
# Out:
#      camera_id  score_mean_x  result_code_x  score_mean_y  result_code_y
# 0          786      0.882213            1.0      0.743150           21.0
# 1         5769      0.943679            4.0      0.801596           37.0
# 2         3743      0.944960            6.0      0.707434           10.0
# 3          788      0.972090            2.0      0.771469           18.0
# 4         1149      0.977158            3.0      0.846750           48.0
# ..         ...           ...            ...           ...            ...
# 914       8442           NaN            NaN      0.999862            1.0
# 915       8830           NaN            NaN      0.999899            1.0
# 916       5337           NaN            NaN      0.999913            2.0
# 917       6094           NaN            NaN      0.999929            1.0
# 918        837           NaN            NaN      0.999963            1.0
#
# [919 rows x 5 columns]

# %%
AI_сamera.isnull().sum()
# Out:
# camera_id          0
# score_mean_x     202
# result_code_x    202
# score_mean_y      29
# result_code_y     29
# dtype: int64

# %%
 AI_сamera.loc[AI_сamera['score_mean_y'].isnull()]
# Out:
#      camera_id  score_mean_x  result_code_x  score_mean_y  result_code_y
# 29        8440      0.995284           14.0           NaN            NaN
# 76         835      0.998636            1.0           NaN            NaN
# 81        8399      0.998671            2.0           NaN            NaN
# 107       6337      0.999153            2.0           NaN            NaN
# 139       7122      0.999445            1.0           NaN            NaN
# 209       5721      0.999685            1.0           NaN            NaN
# 213        750      0.999690            1.0           NaN            NaN
# 230       6178      0.999710            1.0           NaN            NaN
# 279       6506      0.999755            2.0           NaN            NaN
# 288        777      0.999761            1.0           NaN            NaN
# 322       7293      0.999788            4.0           NaN            NaN
# 357       6322      0.999807            1.0           NaN            NaN
# 359       2478      0.999808            4.0           NaN            NaN
# 387       8488      0.999823            1.0           NaN            NaN
# 440       8483      0.999839            2.0           NaN            NaN
# 445       6293      0.999840            2.0           NaN            NaN
# 450       6406      0.999842            1.0           NaN            NaN
# 472       4114      0.999849            2.0           NaN            NaN
# 473       5776      0.999849            1.0           NaN            NaN
# 501       8417      0.999858            5.0           NaN            NaN
# 515       1830      0.999864            2.0           NaN            NaN
# 517       8490      0.999864            4.0           NaN            NaN
# 537       8407      0.999870            5.0           NaN            NaN
# 558       6524      0.999878            3.0           NaN            NaN
# 584       8394      0.999886            4.0           NaN            NaN
# 659       8508      0.999920            2.0           NaN            NaN
# 668       6288      0.999923            1.0           NaN            NaN
# 672       8436      0.999926            1.0           NaN            NaN
# 707       8493      0.999953            1.0           NaN            NaN

# %%
caemra_not_AI = camera_not_AI = AI_сamera.loc[AI_сamera['score_mean_x'].isnull()]

# %%
camera_AI.camera_id.array
# Out:
# <PandasArray>
# [8440,  835, 8399, 6337, 7122, 5721,  750, 6178, 6506,  777, 7293, 6322, 2478,
#  8488, 8483, 6293, 6406, 4114, 5776, 8417, 1830, 8490, 8407, 6524, 8394, 8508,
#  6288, 8436, 8493]
# Length: 29, dtype: int64

# %%
camera_not_AI.camera_id.array
# Out:
# <PandasArray>
# [8889, 8434, 8898, 6378,  878,  827, 6202, 6554, 2657, 6092,
#  ...
#  6278,  871, 8165, 7553, 8402, 8442, 8830, 5337, 6094,  837]
# Length: 202, dtype: int64

# %% [markdown]
# на 29 камерах, новый алгоритм ни разу не ошибсся, в то время, как старый ошибался,

# %%
# test.loc[test['camera_id'] == 8440]
# Out:
#         camera_id          time_check regno_recognize   regno_ai      regno  \
# id
# 2376         8440 2022-04-14 00:15:51       Р648СР152  Р648СР152  Р648СР152
# 3176         8440 2022-04-14 00:21:39       Т313АМ799  Т313АМ799  Т313АМ799
# 6298         8440 2022-04-14 00:43:48       Р648СР132  Р648СР152  Р648СР152
# 10297        8440 2022-04-14 01:15:47       У302АМ791  У302АМ799  У302АМ799
# 10783        8440 2022-04-14 01:19:40        Р951ВК77  Р951ВК799  Р951ВК799
# 10785        8440 2022-04-14 01:19:40       Р951ВК779  Р951ВК799  Р951ВК799
# 16956        8440 2022-04-14 02:33:59       В189СК777  В189СК777  В189СК777
# 18123        8440 2022-04-14 02:53:43       С643АХ777  С663АХ777  С663АХ777
# 20164        8440 2022-04-14 03:33:50        А883УС75  А883УС750  А883УС750
# 25605        8440 2022-04-14 05:20:03       Х048АН799  Х048АН799  Х048АН799
# 31758        8440 2022-04-14 06:21:39        А433ЕР97   А433ЕР97   А433ЕР97
# 57149        8440 2022-04-14 09:15:39       В004УР177  В004УР177  В004УР177
# 58023        8440 2022-04-14 09:21:56       А631СК750  А631СК750  А631СК750
# 65516        8440 2022-04-14 10:09:55       Х764ОМ799  Х764ОМ799  Х764ОМ799
# 79867        8440 2022-04-14 11:39:30       У566ОХ799  У566ОХ799  У566ОХ799
# 84267        8440 2022-04-14 12:05:36       К255ХУ777  К255ХУ777  К255ХУ777
# 86293        8440 2022-04-14 12:17:37       У817КА799  У817КА799  У817КА799
# 87040        8440 2022-04-14 12:21:32       К428ХК777  К428ХК777  К428ХК777
# 88830        8440 2022-04-14 12:31:48       Н388УХ777  Н388УХ777  Н388УХ777
# 90501        8440 2022-04-14 12:41:37       О186МН799  О186МН799  О186МН799
# 93195        8440 2022-04-14 12:57:01       О307ХК777  О307ХК777  О307ХК777
# 94173        8440 2022-04-14 13:02:44       К428ХК777  К428ХК777  К428ХК777
# 94901        8440 2022-04-14 13:07:29       К526МО177  К526МО177  К526МО177
# 99980        8440 2022-04-14 13:36:48       Т977НН777  Т977НН777  Т977НН777
# 107989       8440 2022-04-14 14:21:41        С554СС77   С554СС77   С554СС77
# 120047       8440 2022-04-14 15:27:25        О099СА98   О099СА98  Р995МО799
# 121537       8440 2022-04-14 15:35:22       А953УХ777  А953УХ777  А953УХ777
# 122382       8440 2022-04-14 15:39:57       О700ТХ777  О700ТХ777  О700ТХ777
# 123018       8440 2022-04-14 15:43:24       О906НР750  О906НР750  О906НР750
# 124942       8440 2022-04-14 15:53:29       Е052ОА750  Е052ОА750  Е052ОА750
# 127311       8440 2022-04-14 16:06:39       В496ОР177  В496ОР177  В496ОР177
# 133221       8440 2022-04-14 16:39:40       Е787ОТ799  Е787ОТ799  Е787ОТ799
# 133810       8440 2022-04-14 16:43:14       С445ОС799  С645ОС799  С645ОС799
# 136928       8440 2022-04-14 17:01:15       А070МК197  А070МК197  А070МК197
# 139361       8440 2022-04-14 17:16:59       М503КС799  М503КС799  М503КС799
# 139685       8440 2022-04-14 17:19:00       К102КХ777  К102КХ777  К102КХ777
# 141010       8440 2022-04-14 17:27:41       У626ТМ777  У626ТМ777  У626ТМ777
# 148347       8440 2022-04-14 18:13:45        К717ХС77   К717ХС77   К717ХС77
# 149503       8440 2022-04-14 18:21:45       Е150АТ778  Е150АТ799  Е150АТ799
# 157075       8440 2022-04-14 19:13:43       У210КА777  У210КА777  У210КА777
# 159698       8440 2022-04-14 19:33:44       У954УТ117  Х954УТ197  Х954УТ197
# 160117       8440 2022-04-14 19:36:59       Х319МС750  Х319МС750  Х319МС750
# 160468       8440 2022-04-14 19:39:49       Е521АМ797  Е521АМ799  Е521АМ799
# 160735       8440 2022-04-14 19:41:54       У159ТХ190  У159ТХ190  У159ТХ190
# 163913       8440 2022-04-14 20:07:56       С055СО750  С055СО750  С055СО750
# 165996       8440 2022-04-14 20:29:09       Х383РМ777  Х383РМ777  Х383РМ777
# 168000       8440 2022-04-14 20:49:04       Х559КР791  Х559КР799  Х559КР799
# 170827       8440 2022-04-14 21:15:42       К102ЕХ797  К102ЕХ799  К102ЕХ799
# 180331       8440 2022-04-14 22:27:49       В277ЕУ777  В277ЕУ777  В277ЕУ777
# 183903       8440 2022-04-14 22:51:52       В578МО797  В578МО799  В578МО799
# 186042       8440 2022-04-14 23:05:51       У220ОУ777  К220ОУ777  К220ОУ777
# 190336       8440 2022-04-14 23:33:48       Е170МУ777  Е170МУ777  Е170МУ777
# 192129       8440 2022-04-14 23:45:49        Р859ХК77   Р859ХК77   Р859ХК77
#
#         result_code                                        symbols  \
# id
# 2376              3  ["Р", "6", "4", "8", "С", "Р", "1", "5", "2"]
# 3176              0  ["Т", "3", "1", "3", "А", "М", "7", "9", "9"]
# 6298              4  ["Р", "6", "4", "8", "С", "Р", "1", "5", "2"]
# 10297             2  ["У", "3", "0", "2", "А", "М", "7", "9", "9"]
# 10783             5  ["Р", "9", "5", "1", "В", "К", "7", "9", "9"]
# 10785             1  ["Р", "9", "5", "1", "В", "К", "7", "9", "9"]
# 16956             0  ["В", "1", "8", "9", "С", "К", "7", "7", "7"]
# 18123             4  ["С", "6", "6", "3", "А", "Х", "7", "7", "7"]
# 20164             0  ["А", "8", "8", "3", "У", "С", "7", "5", "0"]
# 25605             0  ["Х", "0", "4", "8", "А", "Н", "7", "9", "9"]
# 31758             3       ["А", "4", "3", "3", "Е", "Р", "9", "7"]
# 57149             0  ["В", "0", "0", "4", "У", "Р", "1", "7", "7"]
# 58023             3  ["А", "6", "3", "1", "С", "К", "7", "5", "0"]
# 65516             0  ["Х", "7", "6", "4", "О", "М", "7", "9", "9"]
# 79867             0  ["У", "5", "6", "6", "О", "Х", "7", "9", "9"]
# 84267             0  ["К", "2", "5", "5", "Х", "У", "7", "7", "7"]
# 86293             0  ["У", "8", "1", "7", "К", "А", "7", "9", "9"]
# 87040             0  ["К", "4", "2", "8", "Х", "К", "7", "7", "7"]
# 88830             0  ["Н", "3", "8", "8", "У", "Х", "7", "7", "7"]
# 90501             0  ["О", "1", "8", "6", "М", "Н", "7", "9", "9"]
# 93195             0  ["О", "3", "0", "7", "Х", "К", "7", "7", "7"]
# 94173             0  ["К", "4", "2", "8", "Х", "К", "7", "7", "7"]
# 94901             0  ["К", "5", "2", "6", "М", "О", "1", "7", "7"]
# 99980             0  ["Т", "9", "7", "7", "Н", "Н", "7", "7", "7"]
# 107989            0       ["С", "5", "5", "4", "С", "С", "7", "7"]
# 120047            0       ["О", "0", "9", "9", "С", "А", "9", "8"]
# 121537            3  ["А", "9", "5", "3", "У", "Х", "7", "7", "7"]
# 122382            0  ["О", "7", "0", "0", "Т", "Х", "7", "7", "7"]
# 123018            0  ["О", "9", "0", "6", "Н", "Р", "7", "5", "0"]
# 124942            0  ["Е", "0", "5", "2", "О", "А", "7", "5", "0"]
# 127311            0  ["В", "4", "9", "6", "О", "Р", "1", "7", "7"]
# 133221            0  ["Е", "7", "8", "7", "О", "Т", "7", "9", "9"]
# 133810            0  ["С", "6", "4", "5", "О", "С", "7", "9", "9"]
# 136928            0  ["А", "0", "7", "0", "М", "К", "1", "9", "7"]
# 139361            0  ["М", "5", "0", "3", "К", "С", "7", "9", "9"]
# 139685            0  ["К", "1", "0", "2", "К", "Х", "7", "7", "7"]
# 141010            0  ["У", "6", "2", "6", "Т", "М", "7", "7", "7"]
# 148347            0       ["К", "7", "1", "7", "Х", "С", "7", "7"]
# 149503            0  ["Е", "1", "5", "0", "А", "Т", "7", "9", "9"]
# 157075            0  ["У", "2", "1", "0", "К", "А", "7", "7", "7"]
# 159698            0  ["Х", "9", "5", "4", "У", "Т", "1", "9", "7"]
# 160117            0  ["Х", "3", "1", "9", "М", "С", "7", "5", "0"]
# 160468            0  ["Е", "5", "2", "1", "А", "М", "7", "9", "9"]
# 160735            0  ["У", "1", "5", "9", "Т", "Х", "1", "9", "0"]
# 163913            0  ["С", "0", "5", "5", "С", "О", "7", "5", "0"]
# 165996            0  ["Х", "3", "8", "3", "Р", "М", "7", "7", "7"]
# 168000            0  ["Х", "5", "5", "9", "К", "Р", "7", "9", "9"]
# 170827            0  ["К", "1", "0", "2", "Е", "Х", "7", "9", "9"]
# 180331            0  ["В", "2", "7", "7", "Е", "У", "7", "7", "7"]
# 183903            0  ["В", "5", "7", "8", "М", "О", "7", "9", "9"]
# 186042            0  ["К", "2", "2", "0", "О", "У", "7", "7", "7"]
# 190336            0  ["Е", "1", "7", "0", "М", "У", "7", "7", "7"]
# 192129            0       ["Р", "8", "5", "9", "Х", "К", "7", "7"]
#
#                                             symbol_scores  \
# id
# 2376    [0.9996562004089355, 0.999874472618103, 0.9999...
# 3176    [0.9999110698699951, 0.9998866319656372, 0.999...
# 6298    [0.9996668100357056, 0.999722421169281, 0.9999...
# 10297   [0.9967741370201111, 0.9990166425704956, 0.999...
# 10783   [0.9999195337295532, 0.9997497200965881, 0.994...
# 10785   [0.9999344348907471, 0.9999686479568481, 0.999...
# 16956   [0.9999251365661621, 0.9994588494300842, 0.999...
# 18123   [0.9996752738952637, 0.9998773336410522, 0.999...
# 20164   [0.9999141693115234, 0.9999692440032959, 0.999...
# 25605   [0.9997346997261047, 0.9998462200164795, 0.999...
# 31758   [0.9998944997787476, 0.999895453453064, 0.9998...
# 57149   [0.9999282360076904, 0.9999445676803589, 0.999...
# 58023   [0.9998785257339478, 0.9998313188552856, 0.999...
# 65516   [0.9999175071716309, 0.9999548196792603, 0.999...
# 79867   [0.9998432397842407, 0.9999654293060303, 0.999...
# 84267   [0.9997699856758118, 0.9999016523361206, 0.999...
# 86293   [0.9998495578765869, 0.9999511241912842, 0.999...
# 87040   [0.9999159574508667, 0.9998859167098999, 0.999...
# 88830   [0.9998000264167786, 0.9999649524688721, 0.999...
# 90501   [0.9997879862785339, 0.9999051094055176, 0.999...
# 93195   [0.9998586177825928, 0.9998668432235718, 0.999...
# 94173   [0.9999102354049683, 0.9998544454574585, 0.999...
# 94901   [0.99985671043396, 0.9999420642852783, 0.99996...
# 99980   [0.999736487865448, 0.9999659061431885, 0.9999...
# 107989  [0.9999337196350098, 0.9999595880508423, 0.999...
# 120047  [0.9988052845001221, 0.9999374151229858, 0.999...
# 121537  [0.9998944997787476, 0.9999130964279175, 0.999...
# 122382  [0.9997830986976624, 0.9998795986175537, 0.999...
# 123018  [0.9998472929000854, 0.9999157190322876, 0.999...
# 124942  [0.9998778104782104, 0.9999457597732544, 0.999...
# 127311  [0.9999282360076904, 0.9998773336410522, 0.999...
# 133221  [0.9998577833175659, 0.9998941421508789, 0.999...
# 133810  [0.999902606010437, 0.9998093247413635, 0.9997...
# 136928  [0.9999017715454102, 0.9998168349266052, 0.999...
# 139361  [0.9998294115066528, 0.9999486207962036, 0.999...
# 139685  [0.9998186230659485, 0.999930739402771, 0.9998...
# 141010  [0.999752938747406, 0.999968409538269, 0.99993...
# 148347  [0.9998989105224609, 0.9999066591262817, 0.999...
# 149503  [0.999365508556366, 0.9999872446060181, 0.9999...
# 157075  [0.999861478805542, 0.9999690055847168, 0.9999...
# 159698  [0.9996553659439087, 0.9998866319656372, 0.999...
# 160117  [0.9997625946998596, 0.9997556805610657, 0.999...
# 160468  [0.9997941851615906, 0.9999164342880249, 0.999...
# 160735  [0.9997586607933044, 0.9999383687973022, 0.999...
# 163913  [0.9998929500579834, 0.9998000264167786, 0.999...
# 165996  [0.9998822212219238, 0.9999134540557861, 0.999...
# 168000  [0.9963027238845825, 0.9996416568756104, 0.998...
# 170827  [0.9997580647468567, 0.999923586845398, 0.9999...
# 180331  [0.9999315738677979, 0.9999158382415771, 0.999...
# 183903  [0.9998735189437866, 0.9999350309371948, 0.999...
# 186042  [0.9996602535247803, 0.9999176263809204, 0.999...
# 190336  [0.9925974607467651, 0.9998942613601685, 0.999...
# 192129  [0.9998571872711182, 0.9998229146003723, 0.999...
#
#                                             length_scores  Hour  \
# id
# 2376    [0.0000000009172423931502749, 0.00000000091145...     0
# 3176    [0.000000016698407989679254, 0.000000016633498...     0
# 6298    [0.0000000014984460339206862, 0.00000000148919...     0
# 10297   [0.00000003309239815507681, 0.0000000331136149...     1
# 10783   [0.00000011239190911283004, 0.0000001129714490...     1
# 10785   [0.00000001844403563211472, 0.0000000185713275...     1
# 16956   [0.000000006691247111945131, 0.000000006752105...     2
# 18123   [0.00000003411288318488914, 0.0000000339676411...     2
# 20164   [0.000000020493287067324673, 0.000000020372318...     3
# 25605   [0.000000006463281909674379, 0.000000006471509...     5
# 31758   [0.00000014131575198916835, 0.0000001418147235...     6
# 57149   [0.00000001129609916716845, 0.0000000112881304...     9
# 58023   [0.000000007662983136924595, 0.000000007641673...     9
# 65516   [0.000000008673238127698824, 0.000000008749369...    10
# 79867   [0.00000001519013714812445, 0.0000000151804648...    11
# 84267   [0.00000005291910198934602, 0.0000000526300105...    12
# 86293   [0.00000000534021227238668, 0.0000000053305955...    12
# 87040   [0.000000025752928678457465, 0.000000025568020...    12
# 88830   [0.000000028183409384041624, 0.000000028106482...    12
# 90501   [0.00000000703470348639712, 0.0000000071161063...    12
# 93195   [0.00000003004260307193363, 0.0000000298494882...    12
# 94173   [0.00000004664412145416463, 0.0000000463212259...    13
# 94901   [0.000000008794883932239372, 0.000000008760963...    13
# 99980   [0.00000001844767361092181, 0.0000000184602040...    13
# 107989  [0.000000039761200554266907, 0.000000039634674...    14
# 120047  [0.000000004437338496643406, 0.000000004437770...    15
# 121537  [0.00000004671879594297934, 0.0000000466573517...    15
# 122382  [0.000000018705728521695164, 0.000000018600063...    15
# 123018  [0.00000002536725496327108, 0.0000000251817056...    15
# 124942  [0.000000007505024157694606, 0.000000007569718...    15
# 127311  [0.000000005309873873926563, 0.000000005319148...    16
# 133221  [0.000000005044816564492294, 0.000000005108860...    16
# 133810  [0.000000016924778023508225, 0.000000016858056...    16
# 136928  [0.000000006090453030793697, 0.000000006113940...    17
# 139361  [0.00000001158952667168478, 0.0000000115020339...    17
# 139685  [0.000000015912133832785003, 0.000000015964390...    17
# 141010  [0.000000018180180916260724, 0.000000018058152...    17
# 148347  [0.00000003952311544708209, 0.0000000392620194...    18
# 149503  [0.000000007844994875938482, 0.000000007891758...    18
# 157075  [0.000000028543661656499353, 0.000000028437314...    19
# 159698  [0.000000041138246587024696, 0.000000041017898...    19
# 160117  [0.00000002428656920017147, 0.0000000241187212...    19
# 160468  [0.0000000031969464853176532, 0.00000000318385...    19
# 160735  [0.0000000030506497328275373, 0.00000000305927...    19
# 163913  [0.000000007914326083380274, 0.000000007924279...    20
# 165996  [0.00000009232007158743727, 0.0000000928941332...    20
# 168000  [0.00000007684227654181086, 0.0000000767590719...    20
# 170827  [0.00000000811814171441938, 0.0000000081771167...    21
# 180331  [0.0000000087747187293985, 0.00000000875050076...    22
# 183903  [0.000000007855937234069188, 0.000000007798668...    22
# 186042  [0.00000008586638955421222, 0.0000000856793960...    23
# 190336  [0.00000002862233650091639, 0.0000000286890191...    23
# 192129  [0.000000010519968896005594, 0.000000010505933...    23
#
#          length_scores_end  index_last_score pos_max_score_symbol  \
# id
# 2376    0.9999991655349731                 9                    6
# 3176      0.99998939037323                 9                    4
# 6298     0.999998927116394                 9                    6
# 10297   0.9999872446060181                 9                    4
# 10783   0.9998781681060791                 9                    3
# 10785   0.9999582767486572                 9                    1
# 16956   0.9999850988388062                 9                    6
# 18123   0.9999192953109741                 9                    6
# 20164   0.9999814033508301                 9                    8
# 25605   0.9999938011169434                 9                    4
# 31758   0.9999028444290161                 8                    5
# 57149   0.9999873638153076                 9                    3
# 58023   0.9999946355819702                 9                    8
# 65516   0.9999932050704956                 9                    2
# 79867   0.9999841451644897                 9                    1
# 84267   0.9999579191207886                 9                    6
# 86293   0.9999808073043823                 9                    2
# 87040   0.9999738931655884                 9                    6
# 88830   0.9999338388442993                 9                    3
# 90501   0.9999667406082153                 9                    2
# 93195   0.9999282360076904                 9                    3
# 94173   0.9999611377716064                 9                    6
# 94901    0.999997615814209                 9                    3
# 99980   0.9999762773513794                 9                    7
# 107989  0.9998822212219238                 8                    6
# 120047  0.9999984502792358                 8                    5
# 121537   0.999916672706604                 9                    2
# 122382  0.9999823570251465                 9                    8
# 123018  0.9999852180480957                 9                    8
# 124942  0.9999904632568359                 9                    6
# 127311  0.9999959468841553                 9                    3
# 133221  0.9999881982803345                 9                    2
# 133810  0.9999887943267822                 9                    6
# 136928  0.9999986886978149                 9                    6
# 139361  0.9999759197235107                 9                    2
# 139685  0.9999756813049316                 9                    6
# 141010  0.9999898672103882                 9                    6
# 148347  0.9999722242355347                 8                    6
# 149503   0.999974250793457                 9                    1
# 157075  0.9999589920043945                 9                    6
# 159698  0.9999933242797852                 9                    6
# 160117  0.9999942779541016                 9                    8
# 160468  0.9999959468841553                 9                    3
# 160735   0.999998927116394                 9                    6
# 163913  0.9999802112579346                 9                    6
# 165996  0.9999651908874512                 9                    6
# 168000  0.9999703168869019                 9                    1
# 170827  0.9999858140945435                 9                    3
# 180331  0.9999604225158691                 9                    6
# 183903  0.9999643564224243                 9                    2
# 186042  0.9999715089797974                 9                    6
# 190336  0.9999783039093018                 9                    6
# 192129  0.9999816417694092                 8                    6
#
#        symbols_max_score  score_max pos_min_score_symbol symbols_min_score  \
# id
# 2376                   1   0.999998                    8                 2
# 3176                   А   0.999978                    7                 9
# 6298                   1   0.999999                    8                 2
# 10297                  А   0.999949                    0                 У
# 10783                  1   0.999950                    7                 9
# 10785                  9   0.999969                    6                 7
# 16956                  7   0.999991                    1                 1
# 18123                  7   0.999994                    3                 3
# 20164                  0   0.999978                    4                 У
# 25605                  А   0.999974                    8                 9
# 31758                  Р   0.999900                    7                 7
# 57149                  4   0.999961                    5                 Р
# 58023                  0   0.999986                    4                 С
# 65516                  6   0.999979                    6                 7
# 79867                  5   0.999965                    6                 7
# 84267                  7   0.999985                    0                 К
# 86293                  1   0.999983                    7                 9
# 87040                  7   0.999988                    1                 4
# 88830                  8   0.999976                    0                 Н
# 90501                  8   0.999990                    6                 7
# 93195                  7   0.999946                    0                 О
# 94173                  7   0.999976                    3                 8
# 94901                  6   0.999987                    4                 М
# 99980                  7   0.999978                    0                 Т
# 107989                 7   0.999984                    3                 4
# 120047                 А   0.999968                    0                 О
# 121537                 5   0.999966                    5                 Х
# 122382                 7   0.999970                    0                 О
# 123018                 0   0.999976                    4                 Н
# 124942                 7   0.999991                    0                 Е
# 127311                 6   0.999990                    5                 Р
# 133221                 8   0.999986                    6                 7
# 133810                 7   0.999913                    7                 9
# 136928                 1   0.999949                    5                 К
# 139361                 0   0.999989                    8                 9
# 139685                 7   0.999979                    4                 К
# 141010                 7   0.999987                    0                 У
# 148347                 7   0.999962                    2                 1
# 149503                 1   0.999987                    0                 Е
# 157075                 7   0.999996                    0                 У
# 159698                 1   0.999953                    0                 Х
# 160117                 0   0.999997                    5                 С
# 160468                 1   0.999979                    8                 9
# 160735                 1   0.999996                    0                 У
# 163913                 7   0.999991                    5                 О
# 165996                 7   0.999976                    5                 М
# 168000                 5   0.999642                    7                 9
# 170827                 2   0.999932                    6                 7
# 180331                 7   0.999991                    5                 У
# 183903                 7   0.999958                    7                 9
# 186042                 7   0.999990                    0                 К
# 190336                 7   0.999981                    0                 Е
# 192129                 7   0.999974                    1                 8
#
#         score_min  score_mean
# id
# 2376     0.998554    0.999723
# 3176     0.999644    0.999880
# 6298     0.995026    0.999311
# 10297    0.996774    0.999238
# 10783    0.962361    0.994827
# 10785    0.998834    0.999795
# 16956    0.999459    0.999888
# 18123    0.999336    0.999799
# 20164    0.999336    0.999859
# 25605    0.999372    0.999790
# 31758    0.998981    0.999723
# 57149    0.999860    0.999928
# 58023    0.999636    0.999903
# 65516    0.999330    0.999793
# 79867    0.998820    0.999756
# 84267    0.999770    0.999926
# 86293    0.998332    0.999732
# 87040    0.999886    0.999931
# 88830    0.999800    0.999931
# 90501    0.997842    0.999649
# 93195    0.999859    0.999908
# 94173    0.999807    0.999901
# 94901    0.999843    0.999925
# 99980    0.999736    0.999922
# 107989   0.999873    0.999936
# 120047   0.998805    0.999766
# 121537   0.999882    0.999932
# 122382   0.999783    0.999881
# 123018   0.999787    0.999909
# 124942   0.999878    0.999944
# 127311   0.999865    0.999921
# 133221   0.997654    0.999622
# 133810   0.562766    0.945977
# 136928   0.999536    0.999841
# 139361   0.999269    0.999748
# 139685   0.999762    0.999906
# 141010   0.999753    0.999936
# 148347   0.999787    0.999899
# 149503   0.999366    0.999833
# 157075   0.999861    0.999938
# 159698   0.999655    0.999849
# 160117   0.999733    0.999890
# 160468   0.987940    0.998019
# 160735   0.999759    0.999918
# 163913   0.999688    0.999879
# 165996   0.999856    0.999924
# 168000   0.994560    0.998112
# 170827   0.999212    0.999788
# 180331   0.999795    0.999935
# 183903   0.999124    0.999723
# 186042   0.999660    0.999853
# 190336   0.992597    0.999067
# 192129   0.999823    0.999918
